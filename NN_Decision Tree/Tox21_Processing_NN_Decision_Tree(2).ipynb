# %% [markdown]
# # Import required libraries :

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense , Input
from tensorflow.keras.optimizers import Adam
from sklearn.tree import plot_tree
from sklearn.model_selection import StratifiedKFold , train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report , confusion_matrix , accuracy_score , roc_curve , roc_auc_score
from sklearn.tree import DecisionTreeClassifier

# %matplotlib inline

# %%
print(tf.__version__)
# Out:
# 2.8.0

# %% [markdown]
# # Import data :

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_x=pd.read_csv("/content/drive/MyDrive/tox21/tox21_x.csv")
y=pd.read_csv("/content/drive/MyDrive/tox21/tox21_y.csv")
y=np.squeeze(y)

# %%
df_x.shape
# Out:
# (7237, 190)

# %%
df_x.head()
# Out:
#           2         3         4  ...           199       200       201
# 0  0.934799  0.177418  0.046765  ...  4.703598e-08  0.166633  0.975867
# 1  0.875932  0.047173  0.029397  ...  4.703598e-08  1.000000  0.738638
# 2  0.967576  0.059713  0.178132  ...  4.703598e-08  0.166633  0.878233
# 3  0.998591  0.009412  0.013743  ...  4.703598e-08  0.166633  0.193474
# 4  0.996279  0.014875  0.248635  ...  4.703598e-08  0.166633  0.353220
#
# [5 rows x 190 columns]

# %% [markdown]
# ### Checking the distribution of labels :

# %%
plt.hist(y,label='freq',bins=2)
plt.legend(loc="upper right")
plt.xticks(range(0,2))
plt.xlabel('toxicity labels of the elements for the NR-AR task')
plt.ylabel('frequency of each label')
plt.show()

# %% [markdown]
# Regarding the imbalanced label set, we are prone to overfitting. So, to mitigate this issue, we will use K-fold cross validation.

# %% [markdown]
# ---------------
# # Neural Network
# ---------------

# %% [markdown]
# ## Data Splitting for Neural Network model

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, y, test_size=0.1, random_state=23)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (6513, 190)
# (6513,)
# (724, 190)
# (724,)

# %%
y_train.value_counts()
# Out:
# 0.0    6233
# 1.0     280
# Name: NR-AR, dtype: int64

# %% [markdown]
# # Building and Training our Neural Network architucture:

# %%
def reg_four_layer_model_config(n1=64,n2=32,n3=16,lnd=0.001):
  input = Input(x_train.shape[1])
  model= Dense(n1, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(lnd))(input)
  model=Dense(n2, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(lnd))(model)
  model=Dense(n3, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(lnd))(model)
  output=Dense(1, activation='sigmoid')(model)
  model=Model(inputs=input,outputs=output)
  return model

# %%
def comp(model,lr=0.05):
  acc=tf.keras.metrics.BinaryAccuracy()
  model.compile(optimizer=Adam(learning_rate=lr),loss='binary_crossentropy', metrics=acc)
  return model

# %%
def plot_model(history):
    df=pd.DataFrame(history.history)
    fig, axs = plt.subplots(1, 2,figsize=(15,5))
    axs[0].plot(df['val_loss'])
    axs[0].plot(df['loss'])
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Loss')
    axs[0].legend(['validation loss','training loss'], loc='upper right')
    axs[0].set_title('Loss of train/validation sets during Epochs')
    axs[0].set_ylim(0,0.5)
    axs[1].plot(df['val_binary_accuracy'])
    axs[1].plot(df['binary_accuracy'])
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('accuracy')
    axs[1].legend(['validation accuracy','training accuracy'], loc='lower right')
    axs[1].set_title('Accuracy of train/validation sets during Epochs')
    axs[1].set_ylim(0.6,1)
    plt.show()

# %% [markdown]
# Because our data is imbalanced, we'll use stratified k-fold cross validation

# %%
strat_kfold = StratifiedKFold(n_splits=10)
fold_num = 1
acc_per_fold = []
loss_per_fold = []
history_per_fold= []
for train_index, test_index in strat_kfold.split(x_train, y_train):
     model=reg_four_layer_model_config()
     comp(model,lr=0.01)

     print('------------------------------------------------------------------------')
     print(f'Training for fold {fold_num} ...')

     history = model.fit(x_train.iloc[train_index], y_train.iloc[train_index], batch_size=32, validation_data=(x_train.iloc[test_index], y_train.iloc[test_index]),epochs=10, verbose=1)
     history_per_fold.append(history)
     scores = model.evaluate(x_train.iloc[test_index], y_train.iloc[test_index] , verbose=0)
     print(f'Score for fold {fold_num}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
     acc_per_fold.append(scores[1] * 100)
     loss_per_fold.append(scores[0])
     fold_num = fold_num + 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/10
# 184/184 [==============================] - 2s 5ms/step - loss: 0.2036 - binary_accuracy: 0.9575 - val_loss: 0.2125 - val_binary_accuracy: 0.9571
# Epoch 2/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1519 - binary_accuracy: 0.9589 - val_loss: 0.1685 - val_binary_accuracy: 0.9571
# Epoch 3/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1437 - binary_accuracy: 0.9671 - val_loss: 0.1264 - val_binary_accuracy: 0.9755
# Epoch 4/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1390 - binary_accuracy: 0.9703 - val_loss: 0.1321 - val_binary_accuracy: 0.9755
# Epoch 5/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1365 - binary_accuracy: 0.9696 - val_loss: 0.1400 - val_binary_accuracy: 0.9586
# Epoch 6/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1339 - binary_accuracy: 0.9708 - val_loss: 0.1257 - val_binary_accuracy: 0.9739
# Epoch 7/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1292 - binary_accuracy: 0.9712 - val_loss: 0.1574 - val_binary_accuracy: 0.9571
# Epoch 8/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1407 - binary_accuracy: 0.9654 - val_loss: 0.1321 - val_binary_accuracy: 0.9617
# Epoch 9/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1286 - binary_accuracy: 0.9724 - val_loss: 0.1239 - val_binary_accuracy: 0.9755
# Epoch 10/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1274 - binary_accuracy: 0.9715 - val_loss: 0.1315 - val_binary_accuracy: 0.9724
# Score for fold 1: loss of 0.13147465884685516; binary_accuracy of 97.23926186561584%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/10
# 184/184 [==============================] - 2s 5ms/step - loss: 0.2133 - binary_accuracy: 0.9526 - val_loss: 0.1762 - val_binary_accuracy: 0.9571
# Epoch 2/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1560 - binary_accuracy: 0.9609 - val_loss: 0.1506 - val_binary_accuracy: 0.9663
# Epoch 3/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1459 - binary_accuracy: 0.9681 - val_loss: 0.1299 - val_binary_accuracy: 0.9724
# Epoch 4/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1387 - binary_accuracy: 0.9700 - val_loss: 0.1301 - val_binary_accuracy: 0.9709
# Epoch 5/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1343 - binary_accuracy: 0.9708 - val_loss: 0.1227 - val_binary_accuracy: 0.9739
# Epoch 6/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1314 - binary_accuracy: 0.9713 - val_loss: 0.1201 - val_binary_accuracy: 0.9724
# Epoch 7/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1345 - binary_accuracy: 0.9686 - val_loss: 0.1311 - val_binary_accuracy: 0.9663
# Epoch 8/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1290 - binary_accuracy: 0.9708 - val_loss: 0.1279 - val_binary_accuracy: 0.9739
# Epoch 9/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1319 - binary_accuracy: 0.9703 - val_loss: 0.1218 - val_binary_accuracy: 0.9755
# Epoch 10/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1292 - binary_accuracy: 0.9710 - val_loss: 0.1220 - val_binary_accuracy: 0.9739
# Score for fold 2: loss of 0.12196801602840424; binary_accuracy of 97.39263653755188%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/10
# 184/184 [==============================] - 2s 5ms/step - loss: 0.2298 - binary_accuracy: 0.9529 - val_loss: 0.1654 - val_binary_accuracy: 0.9571
# Epoch 2/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1557 - binary_accuracy: 0.9577 - val_loss: 0.1419 - val_binary_accuracy: 0.9571
# Epoch 3/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1579 - binary_accuracy: 0.9577 - val_loss: 0.1331 - val_binary_accuracy: 0.9571
# Epoch 4/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1472 - binary_accuracy: 0.9597 - val_loss: 0.1299 - val_binary_accuracy: 0.9571
# Epoch 5/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1478 - binary_accuracy: 0.9613 - val_loss: 0.1342 - val_binary_accuracy: 0.9617
# Epoch 6/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1429 - binary_accuracy: 0.9662 - val_loss: 0.1230 - val_binary_accuracy: 0.9724
# Epoch 7/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1452 - binary_accuracy: 0.9681 - val_loss: 0.1216 - val_binary_accuracy: 0.9709
# Epoch 8/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1411 - binary_accuracy: 0.9684 - val_loss: 0.1565 - val_binary_accuracy: 0.9586
# Epoch 9/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1357 - binary_accuracy: 0.9695 - val_loss: 0.1213 - val_binary_accuracy: 0.9739
# Epoch 10/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1395 - binary_accuracy: 0.9689 - val_loss: 0.1328 - val_binary_accuracy: 0.9755
# Score for fold 3: loss of 0.13280555605888367; binary_accuracy of 97.54601120948792%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/10
# 184/184 [==============================] - 2s 7ms/step - loss: 0.2032 - binary_accuracy: 0.9594 - val_loss: 0.1475 - val_binary_accuracy: 0.9677
# Epoch 2/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1559 - binary_accuracy: 0.9611 - val_loss: 0.1501 - val_binary_accuracy: 0.9616
# Epoch 3/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1459 - binary_accuracy: 0.9674 - val_loss: 0.1357 - val_binary_accuracy: 0.9693
# Epoch 4/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1386 - binary_accuracy: 0.9679 - val_loss: 0.1471 - val_binary_accuracy: 0.9647
# Epoch 5/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1347 - binary_accuracy: 0.9703 - val_loss: 0.1548 - val_binary_accuracy: 0.9616
# Epoch 6/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1343 - binary_accuracy: 0.9707 - val_loss: 0.1327 - val_binary_accuracy: 0.9708
# Epoch 7/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1323 - binary_accuracy: 0.9708 - val_loss: 0.1408 - val_binary_accuracy: 0.9708
# Epoch 8/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1326 - binary_accuracy: 0.9696 - val_loss: 0.1304 - val_binary_accuracy: 0.9693
# Epoch 9/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1289 - binary_accuracy: 0.9720 - val_loss: 0.1295 - val_binary_accuracy: 0.9693
# Epoch 10/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1313 - binary_accuracy: 0.9705 - val_loss: 0.1441 - val_binary_accuracy: 0.9631
# Score for fold 4: loss of 0.14411553740501404; binary_accuracy of 96.31336331367493%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/10
# 184/184 [==============================] - 2s 5ms/step - loss: 0.2072 - binary_accuracy: 0.9539 - val_loss: 0.2174 - val_binary_accuracy: 0.9585
# Epoch 2/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1519 - binary_accuracy: 0.9623 - val_loss: 0.2722 - val_binary_accuracy: 0.9078
# Epoch 3/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1501 - binary_accuracy: 0.9659 - val_loss: 0.1462 - val_binary_accuracy: 0.9662
# Epoch 4/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1415 - binary_accuracy: 0.9684 - val_loss: 0.1515 - val_binary_accuracy: 0.9693
# Epoch 5/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1341 - binary_accuracy: 0.9712 - val_loss: 0.1477 - val_binary_accuracy: 0.9647
# Epoch 6/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1444 - binary_accuracy: 0.9649 - val_loss: 0.1405 - val_binary_accuracy: 0.9724
# Epoch 7/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1365 - binary_accuracy: 0.9698 - val_loss: 0.1389 - val_binary_accuracy: 0.9693
# Epoch 8/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1377 - binary_accuracy: 0.9693 - val_loss: 0.1337 - val_binary_accuracy: 0.9739
# Epoch 9/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1368 - binary_accuracy: 0.9683 - val_loss: 0.1357 - val_binary_accuracy: 0.9724
# Epoch 10/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1339 - binary_accuracy: 0.9696 - val_loss: 0.1368 - val_binary_accuracy: 0.9693
# Score for fold 5: loss of 0.1368008852005005; binary_accuracy of 96.92780375480652%
# ------------------------------------------------------------------------
# Training for fold 6 ...
# Epoch 1/10
# 184/184 [==============================] - 2s 5ms/step - loss: 0.2012 - binary_accuracy: 0.9604 - val_loss: 0.1894 - val_binary_accuracy: 0.9601
# Epoch 2/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1527 - binary_accuracy: 0.9672 - val_loss: 0.1756 - val_binary_accuracy: 0.9601
# Epoch 3/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1381 - binary_accuracy: 0.9708 - val_loss: 0.1647 - val_binary_accuracy: 0.9585
# Epoch 4/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1366 - binary_accuracy: 0.9693 - val_loss: 0.1487 - val_binary_accuracy: 0.9708
# Epoch 5/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1315 - binary_accuracy: 0.9701 - val_loss: 0.1628 - val_binary_accuracy: 0.9662
# Epoch 6/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1295 - binary_accuracy: 0.9705 - val_loss: 0.1509 - val_binary_accuracy: 0.9677
# Epoch 7/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1335 - binary_accuracy: 0.9679 - val_loss: 0.1483 - val_binary_accuracy: 0.9708
# Epoch 8/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1319 - binary_accuracy: 0.9703 - val_loss: 0.1546 - val_binary_accuracy: 0.9693
# Epoch 9/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1283 - binary_accuracy: 0.9710 - val_loss: 0.1458 - val_binary_accuracy: 0.9677
# Epoch 10/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1279 - binary_accuracy: 0.9712 - val_loss: 0.1495 - val_binary_accuracy: 0.9647
# Score for fold 6: loss of 0.14945358037948608; binary_accuracy of 96.46697640419006%
# ------------------------------------------------------------------------
# Training for fold 7 ...
# Epoch 1/10
# 184/184 [==============================] - 2s 5ms/step - loss: 0.2010 - binary_accuracy: 0.9548 - val_loss: 0.1436 - val_binary_accuracy: 0.9585
# Epoch 2/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1540 - binary_accuracy: 0.9575 - val_loss: 0.1420 - val_binary_accuracy: 0.9585
# Epoch 3/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1494 - binary_accuracy: 0.9575 - val_loss: 0.1530 - val_binary_accuracy: 0.9585
# Epoch 4/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1472 - binary_accuracy: 0.9599 - val_loss: 0.1304 - val_binary_accuracy: 0.9724
# Epoch 5/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1408 - binary_accuracy: 0.9681 - val_loss: 0.1270 - val_binary_accuracy: 0.9739
# Epoch 6/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1390 - binary_accuracy: 0.9690 - val_loss: 0.1251 - val_binary_accuracy: 0.9724
# Epoch 7/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1358 - binary_accuracy: 0.9695 - val_loss: 0.1220 - val_binary_accuracy: 0.9739
# Epoch 8/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1347 - binary_accuracy: 0.9696 - val_loss: 0.1281 - val_binary_accuracy: 0.9724
# Epoch 9/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1344 - binary_accuracy: 0.9715 - val_loss: 0.1203 - val_binary_accuracy: 0.9708
# Epoch 10/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1336 - binary_accuracy: 0.9696 - val_loss: 0.1278 - val_binary_accuracy: 0.9739
# Score for fold 7: loss of 0.12781168520450592; binary_accuracy of 97.38863110542297%
# ------------------------------------------------------------------------
# Training for fold 8 ...
# Epoch 1/10
# 184/184 [==============================] - 2s 5ms/step - loss: 0.2083 - binary_accuracy: 0.9533 - val_loss: 0.2089 - val_binary_accuracy: 0.9570
# Epoch 2/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1546 - binary_accuracy: 0.9657 - val_loss: 0.1492 - val_binary_accuracy: 0.9693
# Epoch 3/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1556 - binary_accuracy: 0.9640 - val_loss: 0.1636 - val_binary_accuracy: 0.9570
# Epoch 4/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1464 - binary_accuracy: 0.9599 - val_loss: 0.1409 - val_binary_accuracy: 0.9601
# Epoch 5/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1437 - binary_accuracy: 0.9661 - val_loss: 0.1438 - val_binary_accuracy: 0.9647
# Epoch 6/10
# 184/184 [==============================] - 1s 8ms/step - loss: 0.1418 - binary_accuracy: 0.9678 - val_loss: 0.1392 - val_binary_accuracy: 0.9677
# Epoch 7/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1396 - binary_accuracy: 0.9698 - val_loss: 0.1452 - val_binary_accuracy: 0.9708
# Epoch 8/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1373 - binary_accuracy: 0.9703 - val_loss: 0.1413 - val_binary_accuracy: 0.9647
# Epoch 9/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1333 - binary_accuracy: 0.9710 - val_loss: 0.1376 - val_binary_accuracy: 0.9708
# Epoch 10/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1334 - binary_accuracy: 0.9695 - val_loss: 0.1457 - val_binary_accuracy: 0.9647
# Score for fold 8: loss of 0.14569127559661865; binary_accuracy of 96.46697640419006%
# ------------------------------------------------------------------------
# Training for fold 9 ...
# Epoch 1/10
# 184/184 [==============================] - 2s 5ms/step - loss: 0.1933 - binary_accuracy: 0.9587 - val_loss: 0.1752 - val_binary_accuracy: 0.9585
# Epoch 2/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1514 - binary_accuracy: 0.9647 - val_loss: 0.1725 - val_binary_accuracy: 0.9570
# Epoch 3/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1367 - binary_accuracy: 0.9710 - val_loss: 0.1680 - val_binary_accuracy: 0.9585
# Epoch 4/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1360 - binary_accuracy: 0.9703 - val_loss: 0.1538 - val_binary_accuracy: 0.9662
# Epoch 5/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1374 - binary_accuracy: 0.9707 - val_loss: 0.1532 - val_binary_accuracy: 0.9662
# Epoch 6/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1285 - binary_accuracy: 0.9710 - val_loss: 0.1513 - val_binary_accuracy: 0.9647
# Epoch 7/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1276 - binary_accuracy: 0.9719 - val_loss: 0.1535 - val_binary_accuracy: 0.9631
# Epoch 8/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1289 - binary_accuracy: 0.9705 - val_loss: 0.1558 - val_binary_accuracy: 0.9677
# Epoch 9/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1262 - binary_accuracy: 0.9722 - val_loss: 0.1474 - val_binary_accuracy: 0.9677
# Epoch 10/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1289 - binary_accuracy: 0.9715 - val_loss: 0.1486 - val_binary_accuracy: 0.9647
# Score for fold 9: loss of 0.14862436056137085; binary_accuracy of 96.46697640419006%
# ------------------------------------------------------------------------
# Training for fold 10 ...
# Epoch 1/10
# 184/184 [==============================] - 2s 5ms/step - loss: 0.1989 - binary_accuracy: 0.9577 - val_loss: 0.1442 - val_binary_accuracy: 0.9570
# Epoch 2/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1522 - binary_accuracy: 0.9577 - val_loss: 0.1327 - val_binary_accuracy: 0.9570
# Epoch 3/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1482 - binary_accuracy: 0.9630 - val_loss: 0.1291 - val_binary_accuracy: 0.9708
# Epoch 4/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1437 - binary_accuracy: 0.9662 - val_loss: 0.1254 - val_binary_accuracy: 0.9770
# Epoch 5/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1490 - binary_accuracy: 0.9666 - val_loss: 0.1249 - val_binary_accuracy: 0.9724
# Epoch 6/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1422 - binary_accuracy: 0.9676 - val_loss: 0.1228 - val_binary_accuracy: 0.9800
# Epoch 7/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1438 - binary_accuracy: 0.9671 - val_loss: 0.1219 - val_binary_accuracy: 0.9770
# Epoch 8/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1394 - binary_accuracy: 0.9671 - val_loss: 0.1190 - val_binary_accuracy: 0.9800
# Epoch 9/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1415 - binary_accuracy: 0.9674 - val_loss: 0.1203 - val_binary_accuracy: 0.9785
# Epoch 10/10
# 184/184 [==============================] - 1s 3ms/step - loss: 0.1392 - binary_accuracy: 0.9672 - val_loss: 0.1184 - val_binary_accuracy: 0.9770
# Score for fold 10: loss of 0.11840008199214935; binary_accuracy of 97.69585132598877%

# %%
# Provide average scores
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} +- {np.std(acc_per_fold)}')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.13147465884685516 - Accuracy: 97.23926186561584%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.12196801602840424 - Accuracy: 97.39263653755188%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.13280555605888367 - Accuracy: 97.54601120948792%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.14411553740501404 - Accuracy: 96.31336331367493%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.1368008852005005 - Accuracy: 96.92780375480652%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.14945358037948608 - Accuracy: 96.46697640419006%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.12781168520450592 - Accuracy: 97.38863110542297%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.14569127559661865 - Accuracy: 96.46697640419006%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.14862436056137085 - Accuracy: 96.46697640419006%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.11840008199214935 - Accuracy: 97.69585132598877%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.9904488325119 +- 0.497281970889946
# > Loss: 0.13571456372737883
# ------------------------------------------------------------------------

# %%
for i in range(len(history_per_fold)):
  print(f"--------------------FOLD {i+1} --------------------")
  plot_model(history_per_fold[i])
# Out:
# --------------------FOLD 1 --------------------
# --------------------FOLD 2 --------------------
# --------------------FOLD 3 --------------------
# --------------------FOLD 4 --------------------
# --------------------FOLD 5 --------------------
# --------------------FOLD 6 --------------------
# --------------------FOLD 7 --------------------
# --------------------FOLD 8 --------------------
# --------------------FOLD 9 --------------------
# --------------------FOLD 10 --------------------

# %% [markdown]
# ### Train the network with all the training set

# %%
model=reg_four_layer_model_config()
comp(model,lr=0.01)
history = model.fit(x_train, y_train, batch_size=32,epochs=10,validation_split=0.07, verbose=1)
# Out:
# Epoch 1/10
# 190/190 [==============================] - 2s 5ms/step - loss: 0.2093 - binary_accuracy: 0.9520 - val_loss: 0.1035 - val_binary_accuracy: 0.9803
# Epoch 2/10
# 190/190 [==============================] - 1s 3ms/step - loss: 0.1600 - binary_accuracy: 0.9559 - val_loss: 0.0949 - val_binary_accuracy: 0.9803
# Epoch 3/10
# 190/190 [==============================] - 1s 4ms/step - loss: 0.1538 - binary_accuracy: 0.9596 - val_loss: 0.0991 - val_binary_accuracy: 0.9803
# Epoch 4/10
# 190/190 [==============================] - 1s 3ms/step - loss: 0.1475 - binary_accuracy: 0.9642 - val_loss: 0.0907 - val_binary_accuracy: 0.9868
# Epoch 5/10
# 190/190 [==============================] - 1s 3ms/step - loss: 0.1425 - binary_accuracy: 0.9676 - val_loss: 0.0804 - val_binary_accuracy: 0.9890
# Epoch 6/10
# 190/190 [==============================] - 1s 3ms/step - loss: 0.1365 - binary_accuracy: 0.9695 - val_loss: 0.0921 - val_binary_accuracy: 0.9846
# Epoch 7/10
# 190/190 [==============================] - 1s 3ms/step - loss: 0.1355 - binary_accuracy: 0.9690 - val_loss: 0.1199 - val_binary_accuracy: 0.9759
# Epoch 8/10
# 190/190 [==============================] - 1s 3ms/step - loss: 0.1394 - binary_accuracy: 0.9693 - val_loss: 0.0879 - val_binary_accuracy: 0.9868
# Epoch 9/10
# 190/190 [==============================] - 1s 3ms/step - loss: 0.1322 - binary_accuracy: 0.9695 - val_loss: 0.0811 - val_binary_accuracy: 0.9868
# Epoch 10/10
# 190/190 [==============================] - 1s 3ms/step - loss: 0.1298 - binary_accuracy: 0.9716 - val_loss: 0.0790 - val_binary_accuracy: 0.9868

# %%
plot_model(history)

# %%
model.evaluate(x_test, y_test)
# Out:
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1311 - binary_accuracy: 0.9710
# [0.1310766190290451, 0.9709944725036621]

# %%
y_pred=np.squeeze(model.predict(x_test))
y_pred[y_pred <= 0.5] = 0.
y_pred[y_pred > 0.5] = 1.

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.98      0.99      0.98       690
#      class 1       0.81      0.50      0.62        34
#
#     accuracy                           0.97       724
#    macro avg       0.89      0.75      0.80       724
# weighted avg       0.97      0.97      0.97       724

# %%
cm=pd.DataFrame(confusion_matrix(y_test, y_pred))
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True,fmt='g')
plt.title('Confusion Matrix', size=16)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, np.squeeze(model.predict(x_test)))
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs)

# %%
auc = roc_auc_score(y_test, np.squeeze(model.predict(x_test)))

# %%
plt.plot(fpr,tpr, label=f'ROC curve (area under = {auc :.2f})',color='orange')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ---------------
# # Decision Tree
# ---------------

# %% [markdown]
# ## Data Splitting for decision tree

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, y, test_size=0.1,random_state=50)

# %% [markdown]
# # Building Decision Tree by CP criterion

# %%
tree = DecisionTreeClassifier(criterion='gini')
path =tree.cost_complexity_pruning_path(x_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %% [markdown]
# In the following plot, the maximum effective alpha value is removed, because it is the trivial tree with only one node.

# %%
fig, ax = plt.subplots()
ax.plot(ccp_alphas[:-1], impurities[:-1], marker="o", drawstyle="steps-post")
ax.set_xlabel("effective CP")
ax.set_ylabel("total impurity of leaves")
ax.set_title("Total Impurity vs effective CP for training set")
plt.show()

# %% [markdown]
# As you can see, greater alphas are corresponding to shallower trees with more impurities.

# %%
trees = []
for ccp_alpha in ccp_alphas:
    tree = DecisionTreeClassifier(criterion='gini',random_state=0, ccp_alpha=ccp_alpha)
    tree.fit(x_train, y_train)
    trees.append(tree)

# %%
node_counts = [tree.tree_.node_count for tree in trees]
depth = [tree.tree_.max_depth for tree in trees]
fig, ax = plt.subplots(2, 1)
ax[0].plot(ccp_alphas, node_counts, marker="o", drawstyle="steps-post")
ax[0].set_xlabel("CP")
ax[0].set_ylabel("number of nodes")
ax[0].set_title("Number of nodes vs CP")
ax[1].plot(ccp_alphas, depth, marker="o", drawstyle="steps-post")
ax[1].set_xlabel("CP")
ax[1].set_ylabel("depth of tree")
ax[1].set_title("Depth vs CP")
fig.tight_layout()
fig.set_size_inches(10, 6)
plt.show()

# %% [markdown]
# In the above graphs, we showed that lower alphas are corresponded to more complex trees with more nodes and depth.

# %%
train_scores = [tree.score(x_train, y_train) for tree in trees]
test_scores = [tree.score(x_test, y_test) for tree in trees]

fig, ax = plt.subplots()
ax.set_xlabel("CP")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker="o", label="train", drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker="o", label="test", drawstyle="steps-post")
ax.legend()
fig.set_size_inches(12, 6)
plt.locator_params(axis="x", nbins=10)
plt.show()

# %% [markdown]
# We are going to choose the most suitable alpha for CP, acoording to above graph.

# %%
tree = DecisionTreeClassifier(criterion='gini', ccp_alpha=0.0025)
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0025)

# %%
plt.figure(figsize=(10,10))
plot_tree(tree,filled=True)
plt.show()

# %%
y_pred=tree.predict(x_test)
accuracy_score(y_test,y_pred)*100
# Out:
# 97.37569060773481

# %%
cm=pd.DataFrame(confusion_matrix(y_train, tree.predict(x_train)))
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True,fmt='g')
plt.title('Confusion Matrix of model on Training set', size=16)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.98      1.00      0.99       690
#      class 1       0.86      0.53      0.65        34
#
#     accuracy                           0.97       724
#    macro avg       0.92      0.76      0.82       724
# weighted avg       0.97      0.97      0.97       724

# %%
cm=pd.DataFrame(confusion_matrix(y_test, y_pred))
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True,fmt='g')
plt.title('Confusion Matrix of model on Test set', size=16)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs)

# %%
auc = roc_auc_score(y_test, y_pred)

# %%
plt.plot(fpr,tpr, label=f'ROC curve (area under = {auc :.2f})',color='orange')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Building Decision Tree by modifying depth and number of leaf nodes

# %%
depth = []
for i in range(3,20):
    clf = DecisionTreeClassifier(max_depth=i)
    scores = cross_val_score(estimator=clf, X=x_train, y=y_train, cv=10, n_jobs=4)
    depth.append((i,scores.mean()))
print(depth)
# Out:
# [(3, 0.9715951391441198), (4, 0.9709799930263021), (5, 0.9729762140359807), (6, 0.9723615391139635), (7, 0.971440351323589), (8, 0.9722079292829344), (9, 0.9705196347290153), (10, 0.970519399131115), (11, 0.9686772591482665), (12, 0.9677546577704899), (13, 0.9671406896421739), (14, 0.9666796245511862), (15, 0.9651444686324954), (16, 0.9639165323758636), (17, 0.9634566452743772), (18, 0.9585446646499488), (19, 0.9599252683460083)]

# %%
leaf_node = []
for i in range(3,20):
    clf = DecisionTreeClassifier(max_leaf_nodes=i)
    scores = cross_val_score(estimator=clf, X=x_train, y=y_train, cv=10, n_jobs=4)
    leaf_node.append((i,scores.mean()))
print(leaf_node)
# Out:
# [(3, 0.9685238849151376), (4, 0.9717487489751491), (5, 0.9703667316916871), (6, 0.9723624815055649), (7, 0.9726694655697228), (8, 0.9725156201407932), (9, 0.9720547906477057), (10, 0.9723620103097641), (11, 0.9722086360766353), (12, 0.9726692299718224), (13, 0.9722088716745356), (14, 0.9729762140359804), (15, 0.9723624815055647), (16, 0.972823075400752), (17, 0.9722086360766353), (18, 0.9722086360766353), (19, 0.9728226042049514)]

# %% [markdown]
# So, we should either choose max_leaf_nodes 7 with accuracy 97.26% or max_depth 5 with accuracy 97.31% </br> We'll go with max_depth parameter.

# %%
tree = DecisionTreeClassifier(max_depth=5)
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
plt.figure(figsize=(15,15))
plot_tree(tree,filled=True)
plt.show()

# %%
y_pred=tree.predict(x_test)
accuracy_score(y_test,y_pred)*100
# Out:
# 97.51381215469614

# %%
cm=pd.DataFrame(confusion_matrix(y_train, tree.predict(x_train)))
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True,fmt='g')
plt.title('Confusion Matrix of model on Training set', size=16)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.98      1.00      0.99       690
#      class 1       0.90      0.53      0.67        34
#
#     accuracy                           0.98       724
#    macro avg       0.94      0.76      0.83       724
# weighted avg       0.97      0.98      0.97       724

# %%
cm=pd.DataFrame(confusion_matrix(y_test, y_pred))
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True,fmt='g')
plt.title('Confusion Matrix of model on Test set', size=16)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs)

# %%
auc = roc_auc_score(y_test, y_pred)

# %%
plt.plot(fpr,tpr, label=f'ROC curve (area under = {auc :.2f})',color='orange')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.show()
