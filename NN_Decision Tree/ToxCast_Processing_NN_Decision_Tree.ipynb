# %% [markdown]
# # Import required libraries :

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense , Input
from tensorflow.keras.optimizers import Adam
from sklearn.tree import plot_tree
from sklearn.model_selection import StratifiedKFold , train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report , confusion_matrix , accuracy_score , roc_curve , roc_auc_score
from sklearn.tree import DecisionTreeClassifier

# %matplotlib inline

# %%
print(tf.__version__)
# Out:
# 2.7.0

# %% [markdown]
# # Import data :

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/toxcast/final_toxcast.csv")

# %%
df.head()
# Out:
#           0         1             2  ...       133       134  label
# 0  0.975099  0.013842  5.438167e-01  ...  0.166633  0.307979    0.0
# 1  0.996567  0.006574  9.228296e-01  ...  0.166633  0.673632    0.0
# 2  0.627583  0.010335  4.074888e-10  ...  0.166633  0.591018    0.0
# 3  0.975099  0.013568  5.438167e-01  ...  0.166633  0.187246    0.0
# 4  0.975099  0.013472  5.438167e-01  ...  0.166633  0.317261    0.0
#
# [5 rows x 136 columns]

# %%
df.shape
# Out:
# (7831, 136)

# %%
y=df['label']
df_x=df.drop(['label'],axis=1)

# %% [markdown]
# ### Checking the distribution of labels :

# %%
plt.hist(y,label='freq',bins=2)
plt.legend(loc="upper right")
plt.xticks(range(0,2))
plt.xlabel('toxicity labels of the elements for the NR-AR task')
plt.ylabel('frequency of each label')
plt.show()

# %%
y.value_counts()
# Out:
# 0.0    6116
# 1.0    1715
# Name: label, dtype: int64

# %% [markdown]
# Regarding the imbalanced label set, we are prone to overfitting. So, to mitigate this issue, we will use K-fold cross validation.

# %% [markdown]
# ---------------
# # Neural Network
# ---------------

# %% [markdown]
# ## Data Splitting for Neural Network model

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, y, test_size=0.1, random_state=23)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (7047, 135)
# (7047,)
# (784, 135)
# (784,)

# %%
y_train.value_counts()
# Out:
# 0.0    5499
# 1.0    1548
# Name: label, dtype: int64

# %% [markdown]
# # Building and Training our Neural Network architucture :

# %%
def reg_four_layer_model_config(n1=64,n2=32,n3=16,lnd=0.001):
  input = Input(x_train.shape[1])
  model= Dense(n1, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(lnd))(input)
  model =Dropout(0.3,name='D_O_of_layer1')(model)
  model=Dense(n2, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(lnd))(model)
  model =Dropout(0.2,name='D_O_of_layer2')(model)
  model=Dense(n3, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(lnd))(model)
  model =Dropout(0.1,name='D_O_of_layer3')(model)
  output=Dense(1, activation='sigmoid')(model)
  model=Model(inputs=input,outputs=output)
  return model

# %%
def comp(model,lr=0.05):
  acc=tf.keras.metrics.BinaryAccuracy()
  model.compile(optimizer=Adam(learning_rate=lr),loss='binary_crossentropy', metrics=acc)
  return model

# %%
def plot_model(history):
    df=pd.DataFrame(history.history)
    fig, axs = plt.subplots(1, 2,figsize=(15,5))
    axs[0].plot(df['val_loss'])
    axs[0].plot(df['loss'])
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Loss')
    axs[0].legend(['validation loss','training loss'], loc='upper right')
    axs[0].set_title('Loss of train/validation sets during Epochs')
    axs[0].set_ylim(0,1)
    axs[1].plot(df['val_binary_accuracy'])
    axs[1].plot(df['binary_accuracy'])
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('accuracy')
    axs[1].legend(['validation accuracy','training accuracy'], loc='lower right')
    axs[1].set_title('Accuracy of train/validation sets during Epochs')
    axs[1].set_ylim(0.5,1)
    plt.show()

# %% [markdown]
# Because our data is imbalanced, we'll use stratified k-fold cross validation

# %%
strat_kfold = StratifiedKFold(n_splits=10)
fold_num = 1
acc_per_fold = []
loss_per_fold = []
history_per_fold= []
for train_index, test_index in strat_kfold.split(x_train, y_train):
     model=reg_four_layer_model_config()
     comp(model,lr=0.001)

     print('------------------------------------------------------------------------')
     print(f'Training for fold {fold_num} ...')

     history = model.fit(x_train.iloc[train_index], y_train.iloc[train_index], batch_size=64, validation_data=(x_train.iloc[test_index], y_train.iloc[test_index]),epochs=10, verbose=1)
     history_per_fold.append(history)
     scores = model.evaluate(x_train.iloc[test_index], y_train.iloc[test_index] , verbose=0)
     print(f'Score for fold {fold_num}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
     acc_per_fold.append(scores[1] * 100)
     loss_per_fold.append(scores[0])
     fold_num = fold_num + 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/10
# 100/100 [==============================] - 2s 7ms/step - loss: 0.6594 - binary_accuracy: 0.7774 - val_loss: 0.5606 - val_binary_accuracy: 0.7773
# Epoch 2/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5414 - binary_accuracy: 0.7939 - val_loss: 0.4876 - val_binary_accuracy: 0.8142
# Epoch 3/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5050 - binary_accuracy: 0.8054 - val_loss: 0.4631 - val_binary_accuracy: 0.8270
# Epoch 4/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4781 - binary_accuracy: 0.8136 - val_loss: 0.4396 - val_binary_accuracy: 0.8241
# Epoch 5/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4580 - binary_accuracy: 0.8248 - val_loss: 0.4368 - val_binary_accuracy: 0.8284
# Epoch 6/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4485 - binary_accuracy: 0.8226 - val_loss: 0.4267 - val_binary_accuracy: 0.8170
# Epoch 7/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4331 - binary_accuracy: 0.8351 - val_loss: 0.4180 - val_binary_accuracy: 0.8326
# Epoch 8/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4287 - binary_accuracy: 0.8352 - val_loss: 0.4279 - val_binary_accuracy: 0.8170
# Epoch 9/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4212 - binary_accuracy: 0.8371 - val_loss: 0.4147 - val_binary_accuracy: 0.8227
# Epoch 10/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4111 - binary_accuracy: 0.8387 - val_loss: 0.4151 - val_binary_accuracy: 0.8312
# Score for fold 1: loss of 0.4150561988353729; binary_accuracy of 83.1205666065216%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/10
# 100/100 [==============================] - 1s 5ms/step - loss: 0.6447 - binary_accuracy: 0.7777 - val_loss: 0.5440 - val_binary_accuracy: 0.7986
# Epoch 2/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5374 - binary_accuracy: 0.7982 - val_loss: 0.5112 - val_binary_accuracy: 0.8199
# Epoch 3/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5051 - binary_accuracy: 0.8061 - val_loss: 0.4790 - val_binary_accuracy: 0.8255
# Epoch 4/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4776 - binary_accuracy: 0.8179 - val_loss: 0.4761 - val_binary_accuracy: 0.8099
# Epoch 5/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4599 - binary_accuracy: 0.8195 - val_loss: 0.4600 - val_binary_accuracy: 0.8241
# Epoch 6/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4500 - binary_accuracy: 0.8226 - val_loss: 0.4495 - val_binary_accuracy: 0.8227
# Epoch 7/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4371 - binary_accuracy: 0.8303 - val_loss: 0.4354 - val_binary_accuracy: 0.8426
# Epoch 8/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4262 - binary_accuracy: 0.8368 - val_loss: 0.4309 - val_binary_accuracy: 0.8426
# Epoch 9/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4182 - binary_accuracy: 0.8346 - val_loss: 0.4373 - val_binary_accuracy: 0.8213
# Epoch 10/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4130 - binary_accuracy: 0.8370 - val_loss: 0.4246 - val_binary_accuracy: 0.8397
# Score for fold 2: loss of 0.4246012270450592; binary_accuracy of 83.97163152694702%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/10
# 100/100 [==============================] - 2s 6ms/step - loss: 0.6437 - binary_accuracy: 0.7786 - val_loss: 0.5492 - val_binary_accuracy: 0.7816
# Epoch 2/10
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5415 - binary_accuracy: 0.7909 - val_loss: 0.5107 - val_binary_accuracy: 0.8184
# Epoch 3/10
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5045 - binary_accuracy: 0.8032 - val_loss: 0.4814 - val_binary_accuracy: 0.8241
# Epoch 4/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4813 - binary_accuracy: 0.8127 - val_loss: 0.4661 - val_binary_accuracy: 0.8156
# Epoch 5/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4603 - binary_accuracy: 0.8237 - val_loss: 0.4591 - val_binary_accuracy: 0.8270
# Epoch 6/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4499 - binary_accuracy: 0.8231 - val_loss: 0.4473 - val_binary_accuracy: 0.8284
# Epoch 7/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4391 - binary_accuracy: 0.8283 - val_loss: 0.4466 - val_binary_accuracy: 0.8184
# Epoch 8/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4314 - binary_accuracy: 0.8332 - val_loss: 0.4333 - val_binary_accuracy: 0.8199
# Epoch 9/10
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4176 - binary_accuracy: 0.8348 - val_loss: 0.4359 - val_binary_accuracy: 0.8270
# Epoch 10/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4133 - binary_accuracy: 0.8452 - val_loss: 0.4310 - val_binary_accuracy: 0.8284
# Score for fold 3: loss of 0.43100255727767944; binary_accuracy of 82.83687829971313%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/10
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6874 - binary_accuracy: 0.7390 - val_loss: 0.5766 - val_binary_accuracy: 0.7801
# Epoch 2/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5574 - binary_accuracy: 0.7931 - val_loss: 0.5240 - val_binary_accuracy: 0.8014
# Epoch 3/10
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5150 - binary_accuracy: 0.8117 - val_loss: 0.4972 - val_binary_accuracy: 0.8000
# Epoch 4/10
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4866 - binary_accuracy: 0.8155 - val_loss: 0.4856 - val_binary_accuracy: 0.8000
# Epoch 5/10
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4653 - binary_accuracy: 0.8237 - val_loss: 0.4641 - val_binary_accuracy: 0.8028
# Epoch 6/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4542 - binary_accuracy: 0.8240 - val_loss: 0.4586 - val_binary_accuracy: 0.8099
# Epoch 7/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4378 - binary_accuracy: 0.8335 - val_loss: 0.4473 - val_binary_accuracy: 0.8085
# Epoch 8/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4272 - binary_accuracy: 0.8352 - val_loss: 0.4446 - val_binary_accuracy: 0.8057
# Epoch 9/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4194 - binary_accuracy: 0.8357 - val_loss: 0.4348 - val_binary_accuracy: 0.8128
# Epoch 10/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4100 - binary_accuracy: 0.8403 - val_loss: 0.4353 - val_binary_accuracy: 0.8113
# Score for fold 4: loss of 0.43526971340179443; binary_accuracy of 81.13475441932678%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/10
# 100/100 [==============================] - 1s 5ms/step - loss: 0.6345 - binary_accuracy: 0.7736 - val_loss: 0.5308 - val_binary_accuracy: 0.7816
# Epoch 2/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5401 - binary_accuracy: 0.7961 - val_loss: 0.4909 - val_binary_accuracy: 0.8270
# Epoch 3/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5054 - binary_accuracy: 0.8029 - val_loss: 0.4605 - val_binary_accuracy: 0.8312
# Epoch 4/10
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4775 - binary_accuracy: 0.8138 - val_loss: 0.4463 - val_binary_accuracy: 0.8326
# Epoch 5/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4634 - binary_accuracy: 0.8212 - val_loss: 0.4398 - val_binary_accuracy: 0.8227
# Epoch 6/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4538 - binary_accuracy: 0.8217 - val_loss: 0.4266 - val_binary_accuracy: 0.8312
# Epoch 7/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4343 - binary_accuracy: 0.8289 - val_loss: 0.4221 - val_binary_accuracy: 0.8383
# Epoch 8/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4297 - binary_accuracy: 0.8295 - val_loss: 0.4093 - val_binary_accuracy: 0.8553
# Epoch 9/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4149 - binary_accuracy: 0.8398 - val_loss: 0.4085 - val_binary_accuracy: 0.8525
# Epoch 10/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4094 - binary_accuracy: 0.8437 - val_loss: 0.4033 - val_binary_accuracy: 0.8482
# Score for fold 5: loss of 0.4033149778842926; binary_accuracy of 84.82269644737244%
# ------------------------------------------------------------------------
# Training for fold 6 ...
# Epoch 1/10
# 100/100 [==============================] - 1s 5ms/step - loss: 0.6566 - binary_accuracy: 0.7740 - val_loss: 0.5505 - val_binary_accuracy: 0.7872
# Epoch 2/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5441 - binary_accuracy: 0.8042 - val_loss: 0.5013 - val_binary_accuracy: 0.8057
# Epoch 3/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5086 - binary_accuracy: 0.8072 - val_loss: 0.4757 - val_binary_accuracy: 0.8170
# Epoch 4/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4862 - binary_accuracy: 0.8163 - val_loss: 0.4557 - val_binary_accuracy: 0.8255
# Epoch 5/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4637 - binary_accuracy: 0.8245 - val_loss: 0.4435 - val_binary_accuracy: 0.8241
# Epoch 6/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4517 - binary_accuracy: 0.8275 - val_loss: 0.4315 - val_binary_accuracy: 0.8213
# Epoch 7/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4407 - binary_accuracy: 0.8300 - val_loss: 0.4251 - val_binary_accuracy: 0.8284
# Epoch 8/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4311 - binary_accuracy: 0.8346 - val_loss: 0.4195 - val_binary_accuracy: 0.8298
# Epoch 9/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4254 - binary_accuracy: 0.8344 - val_loss: 0.4094 - val_binary_accuracy: 0.8411
# Epoch 10/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4139 - binary_accuracy: 0.8366 - val_loss: 0.4121 - val_binary_accuracy: 0.8326
# Score for fold 6: loss of 0.4120846092700958; binary_accuracy of 83.26241374015808%
# ------------------------------------------------------------------------
# Training for fold 7 ...
# Epoch 1/10
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6502 - binary_accuracy: 0.7723 - val_loss: 0.5695 - val_binary_accuracy: 0.7801
# Epoch 2/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5396 - binary_accuracy: 0.7908 - val_loss: 0.5115 - val_binary_accuracy: 0.8071
# Epoch 3/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5020 - binary_accuracy: 0.8083 - val_loss: 0.4799 - val_binary_accuracy: 0.8255
# Epoch 4/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4797 - binary_accuracy: 0.8150 - val_loss: 0.4635 - val_binary_accuracy: 0.8270
# Epoch 5/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4589 - binary_accuracy: 0.8234 - val_loss: 0.4544 - val_binary_accuracy: 0.8241
# Epoch 6/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4496 - binary_accuracy: 0.8240 - val_loss: 0.4399 - val_binary_accuracy: 0.8369
# Epoch 7/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4347 - binary_accuracy: 0.8310 - val_loss: 0.4398 - val_binary_accuracy: 0.8270
# Epoch 8/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4287 - binary_accuracy: 0.8341 - val_loss: 0.4277 - val_binary_accuracy: 0.8241
# Epoch 9/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4183 - binary_accuracy: 0.8316 - val_loss: 0.4202 - val_binary_accuracy: 0.8383
# Epoch 10/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4070 - binary_accuracy: 0.8404 - val_loss: 0.4159 - val_binary_accuracy: 0.8326
# Score for fold 7: loss of 0.41591230034828186; binary_accuracy of 83.26241374015808%
# ------------------------------------------------------------------------
# Training for fold 8 ...
# Epoch 1/10
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6811 - binary_accuracy: 0.7476 - val_loss: 0.5728 - val_binary_accuracy: 0.7812
# Epoch 2/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5488 - binary_accuracy: 0.7848 - val_loss: 0.5078 - val_binary_accuracy: 0.8111
# Epoch 3/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5071 - binary_accuracy: 0.7987 - val_loss: 0.4849 - val_binary_accuracy: 0.8082
# Epoch 4/10
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4819 - binary_accuracy: 0.8107 - val_loss: 0.4677 - val_binary_accuracy: 0.8097
# Epoch 5/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4632 - binary_accuracy: 0.8181 - val_loss: 0.4513 - val_binary_accuracy: 0.8111
# Epoch 6/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4430 - binary_accuracy: 0.8271 - val_loss: 0.4425 - val_binary_accuracy: 0.8224
# Epoch 7/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4347 - binary_accuracy: 0.8305 - val_loss: 0.4308 - val_binary_accuracy: 0.8295
# Epoch 8/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4289 - binary_accuracy: 0.8327 - val_loss: 0.4368 - val_binary_accuracy: 0.8125
# Epoch 9/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4181 - binary_accuracy: 0.8390 - val_loss: 0.4185 - val_binary_accuracy: 0.8366
# Epoch 10/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4091 - binary_accuracy: 0.8412 - val_loss: 0.4208 - val_binary_accuracy: 0.8267
# Score for fold 8: loss of 0.4207741916179657; binary_accuracy of 82.67045617103577%
# ------------------------------------------------------------------------
# Training for fold 9 ...
# Epoch 1/10
# 100/100 [==============================] - 2s 12ms/step - loss: 0.6214 - binary_accuracy: 0.7856 - val_loss: 0.5643 - val_binary_accuracy: 0.8054
# Epoch 2/10
# 100/100 [==============================] - 1s 5ms/step - loss: 0.5384 - binary_accuracy: 0.8009 - val_loss: 0.5254 - val_binary_accuracy: 0.8097
# Epoch 3/10
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5070 - binary_accuracy: 0.8064 - val_loss: 0.4978 - val_binary_accuracy: 0.8168
# Epoch 4/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4847 - binary_accuracy: 0.8162 - val_loss: 0.4788 - val_binary_accuracy: 0.8295
# Epoch 5/10
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4622 - binary_accuracy: 0.8241 - val_loss: 0.4643 - val_binary_accuracy: 0.8281
# Epoch 6/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4505 - binary_accuracy: 0.8308 - val_loss: 0.4555 - val_binary_accuracy: 0.8224
# Epoch 7/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4349 - binary_accuracy: 0.8378 - val_loss: 0.4522 - val_binary_accuracy: 0.8097
# Epoch 8/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4281 - binary_accuracy: 0.8362 - val_loss: 0.4443 - val_binary_accuracy: 0.8310
# Epoch 9/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4179 - binary_accuracy: 0.8384 - val_loss: 0.4372 - val_binary_accuracy: 0.8281
# Epoch 10/10
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4151 - binary_accuracy: 0.8378 - val_loss: 0.4403 - val_binary_accuracy: 0.8253
# Score for fold 9: loss of 0.4402851164340973; binary_accuracy of 82.52840638160706%
# ------------------------------------------------------------------------
# Training for fold 10 ...
# Epoch 1/10
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6776 - binary_accuracy: 0.7525 - val_loss: 0.5563 - val_binary_accuracy: 0.7969
# Epoch 2/10
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5531 - binary_accuracy: 0.7974 - val_loss: 0.4939 - val_binary_accuracy: 0.8224
# Epoch 3/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5075 - binary_accuracy: 0.8097 - val_loss: 0.4649 - val_binary_accuracy: 0.8395
# Epoch 4/10
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4865 - binary_accuracy: 0.8138 - val_loss: 0.4552 - val_binary_accuracy: 0.8395
# Epoch 5/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4670 - binary_accuracy: 0.8168 - val_loss: 0.4435 - val_binary_accuracy: 0.8381
# Epoch 6/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4545 - binary_accuracy: 0.8163 - val_loss: 0.4322 - val_binary_accuracy: 0.8423
# Epoch 7/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4371 - binary_accuracy: 0.8282 - val_loss: 0.4281 - val_binary_accuracy: 0.8452
# Epoch 8/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4270 - binary_accuracy: 0.8340 - val_loss: 0.4195 - val_binary_accuracy: 0.8438
# Epoch 9/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4176 - binary_accuracy: 0.8382 - val_loss: 0.4173 - val_binary_accuracy: 0.8466
# Epoch 10/10
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4150 - binary_accuracy: 0.8386 - val_loss: 0.4144 - val_binary_accuracy: 0.8438
# Score for fold 10: loss of 0.41438817977905273; binary_accuracy of 84.375%

# %%
# Provide average scores
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} +- {np.std(acc_per_fold)}')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.4150561988353729 - Accuracy: 83.1205666065216%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.4246012270450592 - Accuracy: 83.97163152694702%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.43100255727767944 - Accuracy: 82.83687829971313%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.43526971340179443 - Accuracy: 81.13475441932678%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.4033149778842926 - Accuracy: 84.82269644737244%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.4120846092700958 - Accuracy: 83.26241374015808%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.41591230034828186 - Accuracy: 83.26241374015808%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.4207741916179657 - Accuracy: 82.67045617103577%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.4402851164340973 - Accuracy: 82.52840638160706%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.41438817977905273 - Accuracy: 84.375%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 83.198521733284 +- 0.9875127375208447
# > Loss: 0.4212689071893692
# ------------------------------------------------------------------------

# %%
for i in range(len(history_per_fold)):
  print(f"--------------------FOLD {i+1} --------------------")
  plot_model(history_per_fold[i])
# Out:
# --------------------FOLD 1 --------------------
# --------------------FOLD 2 --------------------
# --------------------FOLD 3 --------------------
# --------------------FOLD 4 --------------------
# --------------------FOLD 5 --------------------
# --------------------FOLD 6 --------------------
# --------------------FOLD 7 --------------------
# --------------------FOLD 8 --------------------
# --------------------FOLD 9 --------------------
# --------------------FOLD 10 --------------------

# %% [markdown]
# ### Train the network with all the training set

# %%
model=reg_four_layer_model_config()
comp(model,lr=0.001)
history = model.fit(x_train, y_train, batch_size=64,epochs=10,validation_split=0.07, verbose=1)
# Out:
# Epoch 1/10
# 103/103 [==============================] - 1s 6ms/step - loss: 0.6266 - binary_accuracy: 0.7784 - val_loss: 0.5367 - val_binary_accuracy: 0.8036
# Epoch 2/10
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5493 - binary_accuracy: 0.7941 - val_loss: 0.4944 - val_binary_accuracy: 0.8300
# Epoch 3/10
# 103/103 [==============================] - 0s 3ms/step - loss: 0.5054 - binary_accuracy: 0.8059 - val_loss: 0.4656 - val_binary_accuracy: 0.8401
# Epoch 4/10
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4810 - binary_accuracy: 0.8166 - val_loss: 0.4556 - val_binary_accuracy: 0.8401
# Epoch 5/10
# 103/103 [==============================] - 0s 3ms/step - loss: 0.4661 - binary_accuracy: 0.8207 - val_loss: 0.4358 - val_binary_accuracy: 0.8482
# Epoch 6/10
# 103/103 [==============================] - 1s 6ms/step - loss: 0.4450 - binary_accuracy: 0.8239 - val_loss: 0.4246 - val_binary_accuracy: 0.8522
# Epoch 7/10
# 103/103 [==============================] - 1s 7ms/step - loss: 0.4358 - binary_accuracy: 0.8283 - val_loss: 0.4210 - val_binary_accuracy: 0.8502
# Epoch 8/10
# 103/103 [==============================] - 1s 6ms/step - loss: 0.4238 - binary_accuracy: 0.8395 - val_loss: 0.4172 - val_binary_accuracy: 0.8482
# Epoch 9/10
# 103/103 [==============================] - 1s 8ms/step - loss: 0.4159 - binary_accuracy: 0.8361 - val_loss: 0.4145 - val_binary_accuracy: 0.8482
# Epoch 10/10
# 103/103 [==============================] - 1s 6ms/step - loss: 0.4111 - binary_accuracy: 0.8411 - val_loss: 0.4027 - val_binary_accuracy: 0.8563

# %%
plot_model(history)

# %%
model.evaluate(x_test, y_test)
# Out:
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4040 - binary_accuracy: 0.8610
# [0.40398967266082764, 0.8609693646430969]

# %%
y_pred=np.squeeze(model.predict(x_test))
y_pred[y_pred <= 0.5] = 0.
y_pred[y_pred > 0.5] = 1.

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.88      0.96      0.92       617
#      class 1       0.76      0.50      0.61       167
#
#     accuracy                           0.86       784
#    macro avg       0.82      0.73      0.76       784
# weighted avg       0.85      0.86      0.85       784

# %%
cm=pd.DataFrame(confusion_matrix(y_test, y_pred))
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True,fmt='g')
plt.title('Confusion Matrix', size=16)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, np.squeeze(model.predict(x_test)))
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs)

# %%
auc = roc_auc_score(y_test, np.squeeze(model.predict(x_test)))

# %%
plt.plot(fpr,tpr, label=f'ROC curve (area under = {auc :.2f})',color='orange')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ---------------
# # Decision Tree
# ---------------

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, y, test_size=0.1,random_state=50)

# %% [markdown]
# # Building Decision Tree by CP criterion

# %%
tree = DecisionTreeClassifier(criterion='gini')
path =tree.cost_complexity_pruning_path(x_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %% [markdown]
# In the following plot, the maximum effective alpha value is removed, because it is the trivial tree with only one node.

# %%
fig, ax = plt.subplots()
ax.plot(ccp_alphas[:-1], impurities[:-1], marker="o", drawstyle="steps-post")
ax.set_xlabel("effective alpha")
ax.set_ylabel("total impurity of leaves")
ax.set_title("Total Impurity vs effective alpha for training set")
plt.show()

# %% [markdown]
# As you can see, greater alphas are corresponding to shallower trees with more impurities.

# %%
trees = []
for ccp_alpha in ccp_alphas:
    tree = DecisionTreeClassifier(criterion='gini',random_state=0, ccp_alpha=ccp_alpha)
    tree.fit(x_train, y_train)
    trees.append(tree)

# %%
node_counts = [tree.tree_.node_count for tree in trees]
depth = [tree.tree_.max_depth for tree in trees]
fig, ax = plt.subplots(2, 1)
ax[0].plot(ccp_alphas, node_counts, marker="o", drawstyle="steps-post")
ax[0].set_xlabel("alpha")
ax[0].set_ylabel("number of nodes")
ax[0].set_title("Number of nodes vs alpha")
ax[1].plot(ccp_alphas, depth, marker="o", drawstyle="steps-post")
ax[1].set_xlabel("alpha")
ax[1].set_ylabel("depth of tree")
ax[1].set_title("Depth vs alpha")
fig.tight_layout()
fig.set_size_inches(10, 6)
plt.show()

# %% [markdown]
# In the above graphs, we showed that lower alphas are corresponded to more complex trees with more nodes and depth.

# %%
train_scores = [tree.score(x_train, y_train) for tree in trees]
test_scores = [tree.score(x_test, y_test) for tree in trees]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker="o", label="train", drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker="o", label="test", drawstyle="steps-post")
plt.xticks(np.around(np.linspace(0,0.05,20),3),rotation=45)
ax.legend()
fig.set_size_inches(12, 6)
plt.show()

# %%
for i in range(402):
  if train_scores[i]<test_scores[i]:
    print(f' Train accuracy : {train_scores[i]:.4f} Test accuracy : {test_scores[i]:.4f} corresponds to CP : {ccp_alphas[i]:.6f}')
# Out:
#  Train accuracy : 0.8304 Test accuracy : 0.8316 corresponds to CP : 0.001312
#  Train accuracy : 0.8293 Test accuracy : 0.8329 corresponds to CP : 0.001323
#  Train accuracy : 0.8293 Test accuracy : 0.8329 corresponds to CP : 0.001377
#  Train accuracy : 0.8284 Test accuracy : 0.8329 corresponds to CP : 0.001407
#  Train accuracy : 0.8276 Test accuracy : 0.8367 corresponds to CP : 0.001466
#  Train accuracy : 0.8276 Test accuracy : 0.8367 corresponds to CP : 0.001467
#  Train accuracy : 0.8267 Test accuracy : 0.8367 corresponds to CP : 0.001524
#  Train accuracy : 0.8267 Test accuracy : 0.8367 corresponds to CP : 0.001524
#  Train accuracy : 0.8267 Test accuracy : 0.8367 corresponds to CP : 0.001540
#  Train accuracy : 0.8260 Test accuracy : 0.8393 corresponds to CP : 0.001589
#  Train accuracy : 0.8260 Test accuracy : 0.8393 corresponds to CP : 0.001670
#  Train accuracy : 0.8259 Test accuracy : 0.8355 corresponds to CP : 0.002133
#  Train accuracy : 0.8091 Test accuracy : 0.8176 corresponds to CP : 0.002261
#  Train accuracy : 0.8091 Test accuracy : 0.8176 corresponds to CP : 0.002405
#  Train accuracy : 0.8069 Test accuracy : 0.8214 corresponds to CP : 0.003071
#  Train accuracy : 0.8069 Test accuracy : 0.8214 corresponds to CP : 0.004648
#  Train accuracy : 0.8020 Test accuracy : 0.8176 corresponds to CP : 0.006747
#  Train accuracy : 0.7776 Test accuracy : 0.8112 corresponds to CP : 0.014529

# %% [markdown]
# We are going to choose the most suitable alpha for CP, acoording to above graph.

# %%
tree = DecisionTreeClassifier(criterion='gini', ccp_alpha=0.001670)
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.00167)

# %%
plt.figure(figsize=(15,15))
plot_tree(tree,filled=True)
plt.show()

# %%
y_pred=tree.predict(x_test)
accuracy_score(y_test,y_pred)*100
# Out:
# 83.92857142857143

# %%
cm=pd.DataFrame(confusion_matrix(y_train, tree.predict(x_train)))
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True,fmt='g')
plt.title('Confusion Matrix of model on Training set', size=16)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.88      0.93      0.90       636
#      class 1       0.60      0.45      0.51       148
#
#     accuracy                           0.84       784
#    macro avg       0.74      0.69      0.71       784
# weighted avg       0.83      0.84      0.83       784

# %%
cm=pd.DataFrame(confusion_matrix(y_test, y_pred))
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True,fmt='g')
plt.title('Confusion Matrix of model on Test set', size=16)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs)

# %%
auc = roc_auc_score(y_test, y_pred)

# %%
plt.plot(fpr,tpr, label=f'ROC curve (area under = {auc :.2f})',color='orange')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Building Decision Tree by modifying depth and number of leaf nodes

# %%
depth = []
for i in range(3,20):
    clf = DecisionTreeClassifier(max_depth=i)
    scores = cross_val_score(estimator=clf, X=x_train, y=y_train, cv=10, n_jobs=4)
    depth.append((i,scores.mean()))
print(depth)
# Out:
# [(3, 0.8019044165054803), (4, 0.8109836395873631), (5, 0.80999194068343), (6, 0.8118351063829788), (7, 0.8162334784010316), (8, 0.8105587121212121), (9, 0.8155236540941327), (10, 0.8077202208252741), (11, 0.8065864764667957), (12, 0.8092799000644744), (13, 0.8027532640232108), (14, 0.8037449629271439), (15, 0.8019005883301096), (16, 0.8011915699548678), (17, 0.7999125564152161), (18, 0.7966495406189555), (19, 0.793385718891038)]

# %%
leaf_node = []
for i in range(3,20):
    clf = DecisionTreeClassifier(max_leaf_nodes=i)
    scores = cross_val_score(estimator=clf, X=x_train, y=y_train, cv=10, n_jobs=4)
    leaf_node.append((i,scores.mean()))
print(leaf_node)
# Out:
# [(3, 0.8013334139264991), (4, 0.8061597356544166), (5, 0.8061597356544166), (6, 0.8024715909090909), (7, 0.8060205109606706), (8, 0.8088573903932946), (9, 0.8111285058027079), (10, 0.8109866618310766), (11, 0.8111279013539653), (12, 0.810986057382334), (13, 0.8133988152804644), (14, 0.8129732833655705), (15, 0.8136825032237265), (16, 0.8135396518375242), (17, 0.8136810928433269), (18, 0.8125453336557061), (19, 0.8132551579626048)]

# %% [markdown]
# So, we should either choose max_leaf_nodes 9 with accuracy 81.11% or max_depth 7 with accuracy 81.62%
# We'll go with max_depth parameter.

# %%
tree = DecisionTreeClassifier(max_leaf_nodes=9)
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=9)

# %%
plt.figure(figsize=(18,18))
plot_tree(tree,filled=True)
plt.show()

# %%
y_pred=tree.predict(x_test)
accuracy_score(y_test,y_pred)*100
# Out:
# 83.54591836734694

# %%
cm=pd.DataFrame(confusion_matrix(y_train, tree.predict(x_train)))
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True,fmt='g')
plt.title('Confusion Matrix of model on Training set', size=16)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.87      0.93      0.90       636
#      class 1       0.59      0.42      0.49       148
#
#     accuracy                           0.84       784
#    macro avg       0.73      0.68      0.70       784
# weighted avg       0.82      0.84      0.82       784

# %%
cm=pd.DataFrame(confusion_matrix(y_test, y_pred))
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True,fmt='g')
plt.title('Confusion Matrix of model on Test set', size=16)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs)

# %%
auc = roc_auc_score(y_test, y_pred)

# %%
plt.plot(fpr,tpr, label=f'ROC curve (area under = {auc :.2f})',color='orange')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.show()
